# %%
import pandas as pd

CSV_FILE = "jobs.csv"

df = pd.read_csv(CSV_FILE)
df["publication_date"] = pd.to_datetime(df["publication_date"])
df.head()
# Out:
#                                          id  year  keyword  \
# 0  995eca210f3eac097a3656cdbb0c83a8e2f89ff7  2026       AI
# 1  a1f5b1f0c9568c586691d89e77bb2aa46a5bd46c  2026  Backend
# 2  038d933643c62ceae871a3b8b175ddbcd3ec8ea2  2026    Cloud
# 3  a59cc724e829c0a862acba38458c1561c0071e8f  2026       AI
# 4  efaa81b451bb84201787596f1d529ead912ffbb7  2026    Cloud
#
#                                    title                    employer  \
# 0       Senior VRED Visualization Artist                   Avaron AB
# 1               Junior Software Engineer                   Avaron AB
# 2  Senior Application Security Architect                   Avaron AB
# 3                  Projektledare AI-Hubb  Stift Dalarna Science Park
# 4                      SAP BTP Developer                  Incluso AB
#
#   municipality  month publication_date
# 0     Göteborg      5       2026-05-11
# 1   Eskilstuna      5       2026-05-11
# 2     Göteborg      5       2026-05-11
# 3     Borlänge      5       2026-05-08
# 4       Skövde      5       2026-05-08

# %%
from datetime import datetime, timedelta

today = datetime.today()
last_week = today - timedelta(days=7)

# %%
df_last_week = df[df["publication_date"] >= last_week]
df_last_week.head(10)
# Out:
#                                          id  year  keyword  \
# 0  995eca210f3eac097a3656cdbb0c83a8e2f89ff7  2026       AI
# 1  a1f5b1f0c9568c586691d89e77bb2aa46a5bd46c  2026  Backend
# 2  038d933643c62ceae871a3b8b175ddbcd3ec8ea2  2026    Cloud
#
#                                    title   employer municipality  month  \
# 0       Senior VRED Visualization Artist  Avaron AB     Göteborg      5
# 1               Junior Software Engineer  Avaron AB   Eskilstuna      5
# 2  Senior Application Security Architect  Avaron AB     Göteborg      5
#
#   publication_date
# 0       2026-05-11
# 1       2026-05-11
# 2       2026-05-11
