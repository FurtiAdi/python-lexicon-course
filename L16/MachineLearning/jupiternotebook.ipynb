# %%
x = 10

# %%
x
# Out:
# 10

# %%
y = 15

# %%
y
# Out:
# 15

# %%
x = y + 2

# %%
x
# Out:
# 17

# %%
z = 10

# %%
x = z + 2

# %%
x
# Out:
# 12

# %%
def add(a, b):
    return a + b

# %%
add(3, 5)
# Out:
# 8

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## This is a test
# Bla bla bla
